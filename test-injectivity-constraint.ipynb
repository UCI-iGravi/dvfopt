# %% [markdown]
# # Injectivity (Monotonicity) Constraint Toggle — Comparison
#
# Compares correction results across four modes:
# 1. **Jdet only** — gradient-based Jacobian determinant constraint
# 2. **Jdet + Shoelace** — also enforce positive geometric quad-cell areas
# 3. **Jdet + Injectivity** — also enforce monotonicity of deformed coordinates (sufficient for global injectivity on structured grids)
# 4. **Jdet + Shoelace + Injectivity** — all three constraints combined
#
# **Monotonicity constraint:** For a structured grid with unit spacing, global injectivity is guaranteed when:
# - `def_x[i, j+1] > def_x[i, j]` (x increases along rows)
# - `def_y[i+1, j] > def_y[i, j]` (y increases along columns)
#
# This is a sufficient (but not necessary) condition — more restrictive than Jacobian or shoelace alone, and may increase L2 error.

# %%
import numpy as np
import time

from modules.dvfopt import (
    iterative_parallel,
    jacobian_det2D,
    shoelace_det2D,
    _monotonicity_diffs_2d,
)
from modules.dvfviz import (
    plot_grid_before_after,
    plot_checkerboard_before_after,
    plot_neg_jdet_neighborhoods,
)
from modules.testcases import (
    SYNTHETIC_CASES,
    make_deformation,
)

# %% [markdown]
# ## Helper: run all four modes and compare

# %%
JDET_THRESHOLD = 0.01
ERR_TOL = 1e-5

MODES = [
    ("jdet-only",         dict(enforce_shoelace=False, enforce_injectivity=False)),
    ("jdet+shoe",         dict(enforce_shoelace=True,  enforce_injectivity=False)),
    ("jdet+inject",       dict(enforce_shoelace=False, enforce_injectivity=True)),
    ("jdet+shoe+inject",  dict(enforce_shoelace=True,  enforce_injectivity=True)),
]


def summarize(label, deformation, phi):
    """Print Jacobian, shoelace, and monotonicity stats."""
    jac = jacobian_det2D(phi)
    shoe = shoelace_det2D(phi)
    h_mono, v_mono = _monotonicity_diffs_2d(phi[0], phi[1])
    phi_init = np.stack([deformation[-2, 0], deformation[-1, 0]])
    l2 = float(np.sqrt(np.sum((phi - phi_init) ** 2)))
    n_neg_jac = int((jac <= 0).sum())
    n_neg_shoe = int((shoe <= 0).sum())
    min_jac = float(jac.min())
    min_shoe = float(shoe.min())
    min_h = float(h_mono.min())
    min_v = float(v_mono.min())
    mono_ok = min_h >= JDET_THRESHOLD - ERR_TOL and min_v >= JDET_THRESHOLD - ERR_TOL
    print(f"  [{label:20s}]  neg_jdet={n_neg_jac}  min_jdet={min_jac:+.4f}"
          f"  neg_shoe={n_neg_shoe}  min_shoe={min_shoe:+.4f}"
          f"  min_h={min_h:+.4f}  min_v={min_v:+.4f}"
          f"  mono={'OK' if mono_ok else 'FAIL'}  L2={l2:.4f}")
    return dict(n_neg_jac=n_neg_jac, n_neg_shoe=n_neg_shoe,
                min_jac=min_jac, min_shoe=min_shoe,
                min_h=min_h, min_v=min_v, mono_ok=mono_ok, l2=l2)


def compare(key, deformation):
    """Run correction in all modes and visualise."""
    print(f"\n{'='*80}")
    print(f"  {key}  |  shape={deformation.shape[-2:]}")
    print(f"{'='*80}")

    # Initial stats
    phi_init = np.stack([deformation[-2, 0], deformation[-1, 0]])
    jac0 = jacobian_det2D(phi_init)
    shoe0 = shoelace_det2D(phi_init)
    h0, v0 = _monotonicity_diffs_2d(phi_init[0], phi_init[1])
    print(f"  [initial]  neg_jdet={int((jac0 <= 0).sum())}  min_jdet={float(jac0.min()):+.4f}"
          f"  neg_shoe={int((shoe0 <= 0).sum())}  min_shoe={float(shoe0.min()):+.4f}"
          f"  min_h={float(h0.min()):+.4f}  min_v={float(v0.min()):+.4f}")

    results = {}
    for label, kwargs in MODES:
        t0 = time.perf_counter()
        phi = iterative_parallel(
            deformation.copy(), verbose=1, threshold=JDET_THRESHOLD, **kwargs,
        )
        elapsed = time.perf_counter() - t0
        stats = summarize(label, deformation, phi)
        stats["time"] = elapsed
        print(f"  Time: {elapsed:.2f}s")
        results[label] = (phi, stats)

    # Visualisations — grid comparison for each mode
    for label, (phi, stats) in results.items():
        plot_grid_before_after(deformation, phi, title=f"{key} — {label}")

    return results

# %% [markdown]
# ## Synthetic test cases

# %%
for case_key in SYNTHETIC_CASES:
    deformation, msample, fsample = make_deformation(case_key)
    results = compare(case_key, deformation)
# Out:
# ================================================================================
#   01a_10x10_crossing  |  shape=(10, 10)
# ================================================================================
#   [initial]  neg_jdet=9  min_jdet=-1.0246  neg_shoe=10  min_shoe=-0.7716  min_h=-1.4773  min_v=+0.9952
# [init] Grid 10x10  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 9  |  min Jdet: -1.024567
# [iter    1]  serial  fix (  3,  5)  neg_pixels=9
#          -> neg_jdet     0  min_jdet +0.010000  L2 2.2706  win 9  sub-iters 1
# [done] All Jdet > threshold after iter 1
#
# ============================================================
#   SUMMARY  (SLSQP — hybrid parallel)
# ------------------------------------------------------------
#   Grid size        : 10 x 10
#   Iterations       : 1  (serial=1, parallel=0)
#   Neg-Jdet      9 ->     0
#   Min Jdet  -1.024567 -> +0.010000
#   L2 error         : 2.270564
#   Time             : 0.15s
# ============================================================
#   [jdet-only           ]  neg_jdet=0  min_jdet=+0.0100  neg_shoe=4  min_shoe=-0.9718  min_h=-1.9560  min_v=-0.0183  mono=FAIL  L2=2.2706
#   Time: 0.15s
# [init] Grid 10x10  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 9  |  min Jdet: -1.024567
# [iter    1]  serial  fix (  3,  5)  neg_pixels=18
#          -> neg_jdet     0  min_jdet +0.010000  L2 3.0051  win 9  sub-iters 1
# [done] All Jdet > threshold after iter 1
#
# ============================================================
#   SUMMARY  (SLSQP — hybrid parallel)
# ------------------------------------------------------------
#   Grid size        : 10 x 10
#   Iterations       : 1  (serial=1, parallel=0)
#   Neg-Jdet      9 ->     0
#   Min Jdet  -1.024567 -> +0.010000
#   L2 error         : 3.005074
#   Time             : 0.38s
# ============================================================
#   [jdet+shoe           ]  neg_jdet=0  min_jdet=+0.0100  neg_shoe=0  min_shoe=+0.0100  min_h=+0.0029  min_v=+0.9594  mono=FAIL  L2=3.0051
#   Time: 0.38s
# [init] Grid 10x10  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 9  |  min Jdet: -1.024567
# [iter    1]  serial  fix (  3,  6)  neg_pixels=15
#          -> neg_jdet     0  min_jdet +0.010000  L2 3.0057  win 9  sub-iters 1
# [done] All Jdet > threshold after iter 1
#
# ============================================================
#   SUMMARY  (SLSQP — hybrid parallel)
# ------------------------------------------------------------
#   Grid size        : 10 x 10
#   Iterations       : 1  (serial=1, parallel=0)
#   Neg-Jdet      9 ->     0
#   Min Jdet  -1.024567 -> +0.010000
#   L2 error         : 3.005660
#   Time             : 0.09s
# ============================================================
#   [jdet+inject         ]  neg_jdet=0  min_jdet=+0.0100  neg_shoe=0  min_shoe=+0.0100  min_h=+0.0100  min_v=+0.9952  mono=OK  L2=3.0057
#   Time: 0.09s
# [init] Grid 10x10  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 9  |  min Jdet: -1.024567
# [iter    1]  serial  fix (  3,  6)  neg_pixels=18
#          -> neg_jdet     0  min_jdet +0.010000  L2 3.0057  win 9  sub-iters 1
# [done] All Jdet > threshold after iter 1
#
# ============================================================
#   SUMMARY  (SLSQP — hybrid parallel)
# ------------------------------------------------------------
#   Grid size        : 10 x 10
#   Iterations       : 1  (serial=1, parallel=0)
#   Neg-Jdet      9 ->     0
#   Min Jdet  -1.024567 -> +0.010000
#   L2 error         : 3.005661
#   Time             : 0.12s
# ============================================================
#   [jdet+shoe+inject    ]  neg_jdet=0  min_jdet=+0.0100  neg_shoe=0  min_shoe=+0.0100  min_h=+0.0100  min_v=+0.9954  mono=OK  L2=3.0057
#   Time: 0.12s
# c:\Users\Andy\Documents\GitHub\UCI-iGravi\deformation-field-processing\modules\dvfviz.py:842: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0, 0.87, 1])
# ================================================================================
#   01b_10x10_opposite  |  shape=(10, 10)
# ================================================================================
#   [initial]  neg_jdet=6  min_jdet=-1.1540  neg_shoe=7  min_shoe=-0.5943  min_h=-1.1540  min_v=+1.0000
# [init] Grid 10x10  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 6  |  min Jdet: -1.154032
# [iter    1]  serial  fix (  2,  1)  neg_pixels=4
#          -> neg_jdet     0  min_jdet +0.010000  L2 1.4622  win 9  sub-iters 1
# [done] All Jdet > threshold after iter 1
#
# ============================================================
#   SUMMARY  (SLSQP — hybrid parallel)
# ------------------------------------------------------------
#   Grid size        : 10 x 10
#   Iterations       : 1  (serial=1, parallel=0)
#   Neg-Jdet      6 ->     0
#   Min Jdet  -1.154032 -> +0.010000
#   L2 error         : 1.462154
#   Time             : 0.14s
# ============================================================
#   [jdet-only           ]  neg_jdet=0  min_jdet=+0.0100  neg_shoe=3  min_shoe=-0.0987  min_h=-0.3824  min_v=+0.6257  mono=FAIL  L2=1.4622
#   Time: 0.14s
# [init] Grid 10x10  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 6  |  min Jdet: -1.154032
# [iter    1]  serial  fix (  2,  1)  neg_pixels=8
#          -> neg_jdet     0  min_jdet +0.010000  L2 1.4849  win 9  sub-iters 1
# [done] All Jdet > threshold after iter 1
#
# ============================================================
#   SUMMARY  (SLSQP — hybrid parallel)
# ------------------------------------------------------------
#   Grid size        : 10 x 10
#   Iterations       : 1  (serial=1, parallel=0)
#   Neg-Jdet      6 ->     0
#   Min Jdet  -1.154032 -> +0.010000
#   L2 error         : 1.484868
#   Time             : 0.21s
# ============================================================
#   [jdet+shoe           ]  neg_jdet=0  min_jdet=+0.0100  neg_shoe=0  min_shoe=+0.0100  min_h=-0.2613  min_v=+0.6936  mono=FAIL  L2=1.4849
#   Time: 0.21s
# [init] Grid 10x10  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 6  |  min Jdet: -1.154032
# [iter    1]  serial  fix (  2,  1)  neg_pixels=5
#          -> neg_jdet     0  min_jdet +0.010000  L2 1.6128  win 9  sub-iters 1
# [done] All Jdet > threshold after iter 1
#
# ============================================================
#   SUMMARY  (SLSQP — hybrid parallel)
# ------------------------------------------------------------
#   Grid size        : 10 x 10
#   Iterations       : 1  (serial=1, parallel=0)
#   Neg-Jdet      6 ->     0
#   Min Jdet  -1.154032 -> +0.010000
#   L2 error         : 1.612785
#   Time             : 0.07s
# ============================================================
#   [jdet+inject         ]  neg_jdet=0  min_jdet=+0.0100  neg_shoe=0  min_shoe=+0.0100  min_h=+0.0100  min_v=+0.9993  mono=OK  L2=1.6128
#   Time: 0.07s
# [init] Grid 10x10  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 6  |  min Jdet: -1.154032
# [iter    1]  serial  fix (  2,  1)  neg_pixels=8
#          -> neg_jdet     0  min_jdet +0.010000  L2 1.6128  win 9  sub-iters 1
# [done] All Jdet > threshold after iter 1
#
# ============================================================
#   SUMMARY  (SLSQP — hybrid parallel)
# ------------------------------------------------------------
#   Grid size        : 10 x 10
#   Iterations       : 1  (serial=1, parallel=0)
#   Neg-Jdet      6 ->     0
#   Min Jdet  -1.154032 -> +0.010000
#   L2 error         : 1.612785
#   Time             : 0.09s
# ============================================================
#   [jdet+shoe+inject    ]  neg_jdet=0  min_jdet=+0.0100  neg_shoe=0  min_shoe=+0.0100  min_h=+0.0100  min_v=+0.9993  mono=OK  L2=1.6128
#   Time: 0.09s
# ================================================================================
#   01c_20x40_edges  |  shape=(20, 40)
# ================================================================================
#   [initial]  neg_jdet=29  min_jdet=-1.3430  neg_shoe=34  min_shoe=-1.8746  min_h=-2.0808  min_v=-1.5018
# [init] Grid 20x40  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 29  |  min Jdet: -1.343039
# [iter    1]  parallel  batch=5  neg_pixels=26  windows=9-9
#          -> neg_jdet     3  min_jdet -0.321936  L2 2.8895
# [iter    2]  parallel  batch=2  neg_pixels=3  windows=11-11
#          -> neg_jdet     5  min_jdet -0.279748  L2 2.8535
# [iter    3]  serial  fix (  3, 32)  neg_pixels=5
#          -> neg_jdet     1  min_jdet -0.141972  L2 2.9417  win 11  sub-iters 1
# [iter    4]  serial  fix ( 17, 24)  neg_pixels=1
#          -> neg_jdet     0  min_jdet +0.010000  L2 2.9527  win 9  sub-iters 1
# [done] All Jdet > threshold after iter 4
#
# ============================================================
#   SUMMARY  (SLSQP — hybrid parallel)
# ------------------------------------------------------------
#   Grid size        : 20 x 40
#   Iterations       : 4  (serial=2, parallel=2)
#   Neg-Jdet     29 ->     0
#   Min Jdet  -1.343039 -> +0.010000
#   L2 error         : 2.952667
#   Time             : 1.33s
# ============================================================
#   [jdet-only           ]  neg_jdet=0  min_jdet=+0.0100  neg_shoe=30  min_shoe=-1.4011  min_h=-2.0857  min_v=-1.6278  mono=FAIL  L2=2.9527
#   Time: 1.33s
# [init] Grid 20x40  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 29  |  min Jdet: -1.343039
# [iter    1]  parallel  batch=5  neg_pixels=83  windows=9-11
#          -> neg_jdet     2  min_jdet -0.157242  L2 3.8148
# [iter    2]  parallel  batch=2  neg_pixels=16  windows=11-11
#          -> neg_jdet     2  min_jdet -0.157242  L2 3.8535
# [iter    3]  serial  fix (  6, 36)  neg_pixels=8
#          -> neg_jdet     1  min_jdet -0.157242  L2 3.8860  win 13  sub-iters 2
# [iter    4]  serial  fix (  2, 25)  neg_pixels=4
#          -> neg_jdet     1  min_jdet -0.091442  L2 3.8848  win 11  sub-iters 1
# [iter    5]  serial  fix (  2, 30)  neg_pixels=1
#          -> neg_jdet     0  min_jdet +0.010000  L2 3.8919  win 15  sub-iters 4
# [done] All Jdet > threshold after iter 5
#
# ============================================================
#   SUMMARY  (SLSQP — hybrid parallel)
# ------------------------------------------------------------
#   Grid size        : 20 x 40
#   Iterations       : 5  (serial=3, parallel=2)
#   Neg-Jdet     29 ->     0
#   Min Jdet  -1.343039 -> +0.010000
#   L2 error         : 3.891856
#   Time             : 4.79s
# ============================================================
#   [jdet+shoe           ]  neg_jdet=0  min_jdet=+0.0100  neg_shoe=0  min_shoe=+0.0100  min_h=-2.1633  min_v=-1.7536  mono=FAIL  L2=3.8919
#   Time: 4.79s
# [init] Grid 20x40  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 29  |  min Jdet: -1.343039
# [iter    1]  parallel  batch=6  neg_pixels=50  windows=9-11
#          -> neg_jdet     2  min_jdet -0.321490  L2 4.6190
# [iter    2]  parallel  batch=2  neg_pixels=4  windows=11-11
#          -> neg_jdet     5  min_jdet -0.331572  L2 4.5218
# [iter    3]  serial  fix (  3, 32)  neg_pixels=6
#          -> neg_jdet     0  min_jdet +0.009999  L2 4.6679  win 9  sub-iters 1
# [done] All Jdet > threshold after iter 3
#
# ============================================================
#   SUMMARY  (SLSQP — hybrid parallel)
# ------------------------------------------------------------
#   Grid size        : 20 x 40
#   Iterations       : 3  (serial=1, parallel=2)
#   Neg-Jdet     29 ->     0
#   Min Jdet  -1.343039 -> +0.009999
#   L2 error         : 4.667858
#   Time             : 1.59s
# ============================================================
#   [jdet+inject         ]  neg_jdet=0  min_jdet=+0.0100  neg_shoe=25  min_shoe=-0.7106  min_h=+0.0100  min_v=+0.0100  mono=OK  L2=4.6679
#   Time: 1.59s
# [init] Grid 20x40  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 29  |  min Jdet: -1.343039
# [iter    1]  parallel  batch=6  neg_pixels=85  windows=9-11
#          -> neg_jdet     1  min_jdet -0.157242  L2 5.0944
# [iter    2]  serial  fix (  2, 26)  neg_pixels=4
#          -> neg_jdet     1  min_jdet -0.138368  L2 5.1014  win 19  sub-iters 6
# [iter    3]  parallel  batch=2  neg_pixels=16  windows=9-9
#          -> neg_jdet     3  min_jdet -0.075793  L2 5.0741
# [iter    4]  parallel  batch=2  neg_pixels=16  windows=9-9
#          -> neg_jdet     1  min_jdet -0.138905  L2 5.1684
# [iter    5]  parallel  batch=2  neg_pixels=10  windows=9-13
#          -> neg_jdet     4  min_jdet -0.309513  L2 5.0593
# [iter    6]  parallel  batch=3  neg_pixels=16  windows=9-9
#          -> neg_jdet     0  min_jdet +0.010000  L2 5.1219
# [done] All Jdet > threshold after iter 6
#
# ============================================================
#   SUMMARY  (SLSQP — hybrid parallel)
# ------------------------------------------------------------
#   Grid size        : 20 x 40
#   Iterations       : 6  (serial=1, parallel=5)
#   Neg-Jdet     29 ->     0
#   Min Jdet  -1.343039 -> +0.010000
#   L2 error         : 5.121871
#   Time             : 8.72s
# ============================================================
#   [jdet+shoe+inject    ]  neg_jdet=0  min_jdet=+0.0100  neg_shoe=0  min_shoe=+0.0100  min_h=+0.0100  min_v=+0.0100  mono=OK  L2=5.1219
#   Time: 8.72s
# ================================================================================
#   01d_20x40_crossing  |  shape=(20, 40)
# ================================================================================
#   [initial]  neg_jdet=158  min_jdet=-3.3699  neg_shoe=150  min_shoe=-2.9384  min_h=-4.7211  min_v=+0.7268
# [init] Grid 20x40  |  threshold=0.01  |  method=SLSQP  |  workers=24  |  min_window=9
# [init] Neg-Jdet pixels: 158  |  min Jdet: -3.369923
# [iter    1]  serial  fix ( 15, 11)  neg_pixels=142
#          -> neg_jdet    84  min_jdet -3.309977  L2 8.9325  win 19  sub-iters 6
# [iter    2]  serial  fix ( 15, 29)  neg_pixels=75
#          -> neg_jdet    18  min_jdet -2.951166  L2 12.1756  win 19  sub-iters 6
# [iter    3]  serial  fix ( 16, 20)  neg_pixels=16
#          -> neg_jdet    22  min_jdet -2.142723  L2 15.3545  win 19  sub-iters 6
# [iter    4]  parallel  batch=2  neg_pixels=22  windows=11-11
#          -> neg_jdet    36  min_jdet -1.786550  L2 11.1655
# [iter    5]  serial  fix ( 15, 25)  neg_pixels=32
#          -> neg_jdet    18  min_jdet -2.897394  L2 12.5123  win 19  sub-iters 6
# [iter    6]  serial  fix ( 15, 15)  neg_pixels=16
#          -> neg_jdet    18  min_jdet -1.742035  L2 14.2984  win 19  sub-iters 6
# [iter    7]  serial  fix ( 15, 24)  neg_pixels=16
#          -> neg_jdet    18  min_jdet -1.668549  L2 14.0861  win 19  sub-iters 6
# [iter    8]  serial  fix ( 16, 15)  neg_pixels=16
#          -> neg_jdet    18  min_jdet -1.793984  L2 14.3869  win 19  sub-iters 6
# [iter    9]  serial  fix ( 15, 24)  neg_pixels=16
#          -> neg_jdet    18  min_jdet -1.584050  L2 14.1608  win 19  sub-iters 6
# [iter   10]  serial  fix ( 16, 14)  neg_pixels=16
#          -> neg_jdet    17  min_jdet -1.549056  L2 14.7708  win 19  sub-iters 6
# [iter   11]  serial  fix ( 15, 23)  neg_pixels=16
#          -> neg_jdet    17  min_jdet -2.321645  L2 14.5020  win 19  sub-iters 6
# [iter   12]  serial  fix ( 15, 14)  neg_pixels=15
#          -> neg_jdet    18  min_jdet -2.005658  L2 14.3389  win 19  sub-iters 6
# [iter   13]  serial  fix ( 16, 23)  neg_pixels=16
#          -> neg_jdet    18  min_jdet -2.035655  L2 14.5073  win 19  sub-iters 6
# [iter   14]  serial  fix ( 15, 14)  neg_pixels=16
#          -> neg_jdet    18  min_jdet -1.880672  L2 14.4167  win 19  sub-iters 6
# [iter   15]  serial  fix ( 15, 23)  neg_pixels=16
#          -> neg_jdet    18  min_jdet -1.414090  L2 14.4804  win 19  sub-iters 6
# [iter   16]  serial  fix ( 17, 13)  neg_pixels=16
#          -> neg_jdet    16  min_jdet -1.666196  L2 14.8569  win 19  sub-iters 6
# [iter   17]  serial  fix ( 16, 22)  neg_pixels=15
#          -> neg_jdet    16  min_jdet -2.463499  L2 15.2519  win 19  sub-iters 6
# [iter   18]  parallel  batch=2  neg_pixels=14  windows=9-11
#          -> neg_jdet    36  min_jdet -1.960509  L2 11.7068
# [iter   19]  serial  fix ( 15, 18)  neg_pixels=32
#          -> neg_jdet    20  min_jdet -3.456191  L2 13.6837  win 19  sub-iters 6
# [iter   20]  parallel  batch=2  neg_pixels=18  windows=9-13
#          -> neg_jdet    24  min_jdet -2.590658  L2 13.3773
# [iter   21]  serial  fix ( 14, 13)  neg_pixels=24
#          -> neg_jdet    18  min_jdet -2.977090  L2 12.5910  win 19  sub-iters 6
# [iter   22]  serial  fix ( 16, 22)  neg_pixels=16
#          -> neg_jdet    18  min_jdet -1.842975  L2 15.1995  win 19  sub-iters 6
# [iter   23]  parallel  batch=2  neg_pixels=16  windows=9-9
#          -> neg_jdet    24  min_jdet -2.333181  L2 13.6983
# [iter   24]  parallel  batch=2  neg_pixels=23  windows=9-9
#          -> neg_jdet    33  min_jdet -1.081090  L2 14.2570
# [iter   25]  parallel  batch=3  neg_pixels=32  windows=9-11
#          -> neg_jdet    41  min_jdet -2.287830  L2 11.6066
# [iter   26]  parallel  batch=2  neg_pixels=40  windows=11-11
#          -> neg_jdet    27  min_jdet -2.938879  L2 11.8762
# [iter   27]  parallel  batch=2  neg_pixels=25  windows=9-13
#          -> neg_jdet    37  min_jdet -1.881841  L2 12.1238
# [iter   28]  parallel  batch=2  neg_pixels=33  windows=11-13
#          -> neg_jdet    30  min_jdet -1.960552  L2 11.8556
# [iter   29]  parallel  batch=2  neg_pixels=27  windows=9-11
#          -> neg_jdet    45  min_jdet -2.205771  L2 9.8112
# [iter   30]  parallel  batch=2  neg_pixels=40  windows=11-11
#          -> neg_jdet    28  min_jdet -2.879853  L2 11.9868
# [iter   31]  parallel  batch=2  neg_pixels=26  windows=9-13
#          -> neg_jdet    37  min_jdet -3.042866  L2 11.4554
# [iter   32]  parallel  batch=2  neg_pixels=33  windows=11-15
#          -> neg_jdet    21  min_jdet -3.103543  L2 12.1137
# [iter   33]  parallel  batch=2  neg_pixels=19  windows=9-13
#          -> neg_jdet    36  min_jdet -2.891373  L2 11.4183
# [iter   34]  parallel  batch=2  neg_pixels=32  windows=11-13
#          -> neg_jdet    27  min_jdet -1.836584  L2 11.9691
# [iter   35]  serial  fix ( 15, 19)  neg_pixels=24
#          -> neg_jdet    20  min_jdet -2.234937  L2 15.1792  win 19  sub-iters 6
# [iter   36]  parallel  batch=2  neg_pixels=20  windows=9-11
#          -> neg_jdet    30  min_jdet -2.134966  L2 12.7390
# [iter   37]  serial  fix ( 14, 24)  neg_pixels=28

# %% [markdown]
# ## Summary table
#
# Collect results for all cases side-by-side.

# %%
import pandas as pd

rows = []
for case_key in SYNTHETIC_CASES:
    deformation, _, _ = make_deformation(case_key)

    for label, kwargs in MODES:
        phi = iterative_parallel(
            deformation.copy(), verbose=0, threshold=JDET_THRESHOLD, **kwargs,
        )
        jac = jacobian_det2D(phi)
        shoe = shoelace_det2D(phi)
        h, v = _monotonicity_diffs_2d(phi[0], phi[1])
        phi_init = np.stack([deformation[-2, 0], deformation[-1, 0]])
        l2 = float(np.sqrt(np.sum((phi - phi_init) ** 2)))
        rows.append(dict(
            case=case_key, mode=label,
            neg_jdet=int((jac <= 0).sum()),
            min_jdet=float(jac.min()),
            neg_shoe=int((shoe <= 0).sum()),
            min_shoe=float(shoe.min()),
            min_h_mono=float(h.min()),
            min_v_mono=float(v.min()),
            L2=l2,
        ))

df = pd.DataFrame(rows)
df.style.format({
    "min_jdet": "{:+.4f}", "min_shoe": "{:+.4f}",
    "min_h_mono": "{:+.4f}", "min_v_mono": "{:+.4f}", "L2": "{:.4f}",
})
